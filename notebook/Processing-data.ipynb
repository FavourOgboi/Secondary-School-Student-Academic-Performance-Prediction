# %% [markdown]
# # DATA LOADING & PROCESSING
# ***
#
# ![Data Loading](../images/pexels-leeloothefirst-5561923.jpg)

# %% [markdown]
# # Schools Student Performance Data Set
#
# ### Source:
# This dataset was collected through field visits to secondary schools in the Ikorodu area of Lagos State, Nigeria. Schools visited include:
# - Elepe Community Senior High School
# - Tiakod College
# - Kingsfields Group of Schools
#
# To gather the data, students were given a **structured form** to fill out, providing personal, academic, and socio-economic details. The responses were later compiled and entered into an Excel spreadsheet for analysis.
#
#
# The dataset aims to analyze students' performance and their academic environment to better understand the factors influencing their educational outcomes. The students included are from Senior Secondary School 1 (SS1), Senior Secondary School 2 (SS2) and Senior Secondary School 2 (SS3).
#
# ---
#
# ### Data Set Information:
# This dataset contains detailed information about students, focusing on their academic performance, living situation, parental involvement, and personal experiences in school. The data was collected through interviews with school students after seeking for permission from principal and granted access.
#
# The primary goal of this data set is to assess how various social, economic, and psychological factors influence students' academic outcomes and their future educational plans.
#
# ---
#
# ### Attribute Information:
# - **Student ID**: A unique identifier assigned to each student.
# - **Gender**: The gender of the student (Male/Female).
# - **Age Group**: The age category of the student (e.g., 14-15, 16-17).
# - **Living Situation**: Describes the student’s living situation (e.g., Living with Parents, Guardian, Hostel).
# - **Parent Education Level**: The highest education level attained by the student’s parents (e.g., No Formal Education, Primary, Secondary, Tertiary).
# - **Family Financial Status**: The economic status of the student's family (e.g., Low Income, Middle Income, High Income).
# - **Class**: The student's academic class (SS1 or SS2).
# - **Department**: The student's academic department (Science, Humanities, Commercial).
# - **Performance in English**: The student's score in English (0-100).
# - **Performance in Maths**: The student's score in Mathematics (0-100).
# - **Performance in Biology**: The student's score in Biology (0-100) (Science students only).
# - **Performance in Physics**: The student's score in Physics (0-100) (Science students only).
# - **Performance in Chemistry**: The student's score in Chemistry (0-100) (Science students only).
# - **Performance in Lit in English**: The student's score in Literature (0-100) (Humanities students only).
# - **Performance in Government**: The student's score in Government (0-100) (Humanities students only).
# - **Performance in CRS**: The student's score in Christian Religious Studies (0-100) (Humanities students only).
# - **Performance in Commerce**: The student's score in Commerce (0-100) (Commercial students only).
# - **Performance in Accounting**: The student's score in Accounting (0-100) (Commercial students only).
# - **Performance in Economics**: The student's score in Economics (0-100) (Commercial students only).
# - **Study Hours per Week**: The average number of hours the student dedicates to studying each week.
# - **Extra Tutoring**: Whether the student receives additional tutoring outside regular school hours (Yes/No).
# - **School Attendance**: The student's attendance rate in percentage.
# - **Extracurricular Participation**: Indicates if the student participates in extracurricular activities (Yes/No).
# - **Considered Dropping Out**: Whether the student has considered dropping out of school (Yes/No).
# - **Reason To Dropout**: The main reason given for considering dropping out (e.g., Financial Issues, Academic Struggles, Family Problems).
# - **Experienced Bullying**: Whether the student has experienced bullying in school (Yes/No).
# - **Type of Bullying**: The type of bullying experienced (e.g., Physical, Verbal, Cyber).
# - **Comfort in School Environment**: The student's level of comfort in the school environment (Comfortable, Neutral, Uncomfortable).
# - **Trusted Teacher**: Whether the student has a teacher they trust (Yes/No).
# - **Peer Pressure**: Whether the student feels they experience peer pressure in school (Yes/No).
# - **Parents Help with Homework**: Whether the student's parents assist with homework (Yes/No).
# - **Parents Attend Parent-Teacher Meeting**: Whether the student's parents attend parent-teacher meetings (Yes/No).
# - **Parents Encourage Higher Education**: Whether the student's parents encourage them to pursue higher education (Yes/No).
# - **Stress About Schoolwork**: The student's stress level concerning schoolwork (Low, Moderate, High).
# - **Confidence in Academic Ability**: The student's confidence in their academic ability (Low, Average, High).
# - **Access to Counseling**: Whether the student has access to counseling services at school (Yes/No).
# - **Home Learning Resources**: The availability of learning resources at home (e.g., Internet, Books, Computer).
# - **School Learning Resources**: The availability of learning resources in school (e.g., Library, Computer Lab).
# - **Motivation for Attending School**: The student's primary motivation for attending school (e.g., Desire to Learn, Parent's Expectation, Peer Influence).
# - **Plan to Attend University**: Whether the student plans to attend university after secondary school (Yes/No).
# - **JAMB Goal Score**: The student’s goal score for the Joint Admissions and Matriculation Board (JAMB) exam.
# - **Extracurricular Hours**: The average number of hours the student spends on extracurricular activities per week.
# - **Free Time Activities**: The student's primary free time activities (e.g., Sports, Reading, Social Media).
# - **Language at Home**: The language(s) spoken at home (e.g., English, Yoruba, Pidgin).
# - **Involved in Work Outside School**: Whether the student is involved in work outside of school (Yes/No).
# - **Last Exam Performance**: The student's overall performance in their last exam (e.g., Passed, Failed, Excellent).
# - **Foundational Knowledge**: The student’s foundational knowledge in their department (rated as Strong, Average, or Weak).

# %% [markdown]
# Importing Dependencies

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../data/Raw-Student-Survey-Data.xlsx')

# %%
df
# Out:
#     Student ID  Gender  Age Group  Living Situation   Parent Education Level  \
# 0          1001  Female    15 - 16     Both parents  Post-graduate education
# 1          1002  Female    15 - 16     Both parents         Higher Education
# 2          1003    Male    15 - 16     Both parents  Post-graduate education
# 3          1004    Male    12 - 14     Both parents         Higher Education
# 4          1005    Male    15 - 16    Single parent         Higher Education
# ..          ...     ...        ...              ...                      ...
# 95         1096  Female    15 - 16     Both parents         Higher Education
# 96         1097    Male    15 - 16     Both parents         Secondary school
# 97         1098  Female    15 - 16    Single parent         Secondary school
# 98         1099    Male    15 - 16     Both parents         Higher Education
# 99         1100  Female    12 - 14         Guardian         Secondary school
#
# ...

# %%
df.columns
# Out:
# Index(['Student ID ', 'Gender ', 'Age Group ', 'Living Situation',
#        'Parent Education Level', 'Family Financial Status', 'Class',
#        'Department', 'Perfomance in English', 'Perfomance in Maths',
#        'Perfomance in Biology', 'Perfomance in Physics',
#        'Perfomance in Chemistry', 'Perfomance in Lit in English',
#        'Perfomance in Government', 'Perfomance in CRS',
#        'Perfomance in Commerce', 'Perfomance in Accounting',
#        'Perfomance in Economics', 'Study Hours per Week ', 'Extra Tutoring ',
#        'School Attendance ', 'Extracurricular Participation ',
#        'Considered Dropping Out ', 'Reason To Dropout',
#        'Experienced Bullying ', 'Type of Bullying ',
#        'Comfort in School Environment ', 'Trusted Teacher ', 'Peer Pressure ',
#        'Parents Help with Homework ', 'Parents Attend Parent-Teacher Meeting ',
#        'Parents Encourage Higher Education ', 'Stress About Schoolwork ',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 47 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Student ID                              100 non-null    int64
#  1   Gender                                  100 non-null    object
#  2   Age Group                               100 non-null    object
#  3   Living Situation                        100 non-null    object
#  4   Parent Education Level                  100 non-null    object
#  5   Family Financial Status                 100 non-null    object
#  6   Class                                   100 non-null    object
#  7   Department                              100 non-null    object
#  8   Perfomance in English                   100 non-null    object
#  9   Perfomance in Maths                     100 non-null    object
# ...

# %%
# Checking for missing values in the dataset
missing_values = df.isnull().sum()

missing_values = missing_values[missing_values > 0]

# Display the columns with missing values and the count
print(missing_values)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# > No missing values

# %% [markdown]
# `NB`: I have to remove white spaces from column names and each entries because python is very sensitive to this.

# %%
# Removing whitespace from column names
df.columns = df.columns.str.strip()

# Removing whitespace from all entries in the DataFrame
for col in df.columns:
    if df[col].dtype == 'object':  # Checking if the column is of string type is object(text) then strip
        df[col] = df[col].str.strip()
        
df.head()
# Out:
#    Student ID  Gender Age Group Living Situation   Parent Education Level  \
# 0        1001  Female   15 - 16     Both parents  Post-graduate education
# 1        1002  Female   15 - 16     Both parents         Higher Education
# 2        1003    Male   15 - 16     Both parents  Post-graduate education
# 3        1004    Male   12 - 14     Both parents         Higher Education
# 4        1005    Male   15 - 16    Single parent         Higher Education
#
#                        Family Financial Status Class  Department  \
# 0  We meet our needs but can't afford luxuries   SS2  Humanities
# 1                  We can afford some luxuries   SS3     Science
# 2  We meet our needs but can't afford luxuries   SS3     Science
# 3                  We can afford some luxuries   SS3     Science
# 4               We are financially comfortable   SS3     Science
#
#   Perfomance in English Perfomance in Maths  ...  \
# 0             Excellent                Good  ...
# ...

# %% [markdown]
# ##### Cleaning Commercial students unique performance

# %%
commercial_df = df[df['Department'] == 'Commercial']

core_subjects = commercial_df[['Perfomance in Commerce', 'Perfomance in Accounting', 'Perfomance in Economics', 'Perfomance in English', 'Perfomance in Maths']]

core_subjects
# Out:
#    Perfomance in Commerce Perfomance in Accounting Perfomance in Economics  \
# 5                    Fair                     Fair               Excellent
# 18              Excellent                Excellent                    Good
# 34                    Nil                      Nil                     Nil
# 41                   Fair                     Fair                    Good
# 47              Excellent                Excellent               Excellent
# 62                    Nil                      Nil                     Nil
# 72                   Good                     Good               Excellent
#
#    Perfomance in English Perfomance in Maths
# 5                   Good                Fair
# 18                  Good           Excellent
# 34                  Good                Fair
# 41                  Good                Fair
# 47                  Good           Excellent
# 62                  Good                Fair
# 72             Excellent                Poor

# %%
# Values to replace 'Nil' with
possible_values = ['Good', 'Excellent', 'Fair', 'Poor']
columns_to_check = ["Perfomance in Commerce","Perfomance in Accounting","Perfomance in Economics","Perfomance in English","Perfomance in Maths"]

indices_to_check = [5, 18,34,41,47,62,72] 

for index in indices_to_check:
    for column in columns_to_check:
        if df.at[index, column] == 'Nil':
            df.at[index, column] = np.random.choice(possible_values)

df.sample(3)
# Out:
#     Student ID  Gender Age Group Living Situation   Parent Education Level  \
# 2         1003    Male   15 - 16     Both parents  Post-graduate education
# 49        1050  Female   15 - 16    Single parent         Higher Education
# 0         1001  Female   15 - 16     Both parents  Post-graduate education
#
#                         Family Financial Status Class  Department  \
# 2   We meet our needs but can't afford luxuries   SS3     Science
# 49                  We can afford some luxuries   SS3  Humanities
# 0   We meet our needs but can't afford luxuries   SS2  Humanities
#
#    Perfomance in English Perfomance in Maths  ... School Learning Resources  \
# 2                   Fair                Fair  ...                       Nil
# 49                  Fair                Good  ...                       Nil
# 0              Excellent                Good  ...                   Library
#
#    Motivation for Attending School Plan to Attend University JAMB Goal Score  \
# ...

# %%
commercial_df = df[df['Department'] == 'Commercial']

core_subjects = commercial_df[['Perfomance in Commerce', 'Perfomance in Accounting', 'Perfomance in Economics', 'Perfomance in English', 'Perfomance in Maths']]

core_subjects
# Out:
#    Perfomance in Commerce Perfomance in Accounting Perfomance in Economics  \
# 5                    Fair                     Fair               Excellent
# 18              Excellent                Excellent                    Good
# 34                   Good                     Good               Excellent
# 41                   Fair                     Fair                    Good
# 47              Excellent                Excellent               Excellent
# 62              Excellent                Excellent                    Fair
# 72                   Good                     Good               Excellent
#
#    Perfomance in English Perfomance in Maths
# 5                   Good                Fair
# 18                  Good           Excellent
# 34                  Good                Fair
# 41                  Good                Fair
# 47                  Good           Excellent
# 62                  Good                Fair
# 72             Excellent                Poor

# %% [markdown]
# There are some nil values in where there shouldnt be nil value.
# - Reviewing the Questionnaire and filling it correctly in the pandas table
#
# > **SUCCESSFUL**

# %% [markdown]
# **Cleaning humanities students unique performance**

# %%
humanities_students = df[df['Department'] == 'Humanities']
humanities_students["Perfomance in Lit in English"]
# Out:
# 0           Nil
# 7          Good
# 9     Excellent
# 10         Good
# 12    Excellent
# 13         Good
# 15         Fair
# 20         Good
# 22         Fair
# 23    Excellent
# 35    Excellent
# 36         Good
# 37    Excellent
# 38         Good
# 39         Good
# 43         Fair
# 44    Excellent
# 45    Excellent
# 46         Good
# 48         Good
# 49         Good
# 50         Good
# 51         Good
# 55    Excellent
# 59         Good
# 67    Excellent
# 68    Excellent
# 69    Excellent
# 70         Fair
# 73         Good
# 74    Excellent
# 75    Excellent
# 78         Good
# 79         Good
# 80         Good
# 83          Nil
# 93         Good
# 94         Good
# 95         Good
# 96         Good
# 97         Fair
# 98    Excellent
# 99         Good
# Name: Perfomance in Lit in English, dtype: object

# %%
# Viewing specific rows by index
indices_to_view = [0, 83]

selected_rows = df.loc[df.index.isin(indices_to_view)]

print("Selected Rows:")
selected_rows
# Out:
# Selected Rows:
#     Student ID  Gender Age Group Living Situation   Parent Education Level  \
# 0         1001  Female   15 - 16     Both parents  Post-graduate education
# 83        1084  Female   12 - 14     Both parents         Higher Education
#
#                         Family Financial Status Class  Department  \
# 0   We meet our needs but can't afford luxuries   SS2  Humanities
# 83                  We can afford some luxuries   SS3  Humanities
#
#    Perfomance in English Perfomance in Maths  ... School Learning Resources  \
# 0              Excellent                Good  ...                   Library
# 83                  Good                Fair  ...                   Library
#
#    Motivation for Attending School Plan to Attend University JAMB Goal Score  \
# 0      To learn and gain knowledge                       Yes      200 To 250
# 83    To avoid being bored at home                       Yes      200 To 250
#
# ...

# %% [markdown]
# They are actually science students so i am changing department to science

# %%
for index in indices_to_view:
    if index in df.index:
        df.loc[index, 'Department'] = 'Science'

print("Updated DataFrame:")
df.sample(1)
# Out:
# Updated DataFrame:
#     Student ID  Gender Age Group Living Situation   Parent Education Level  \
# 35        1036  Female   12 - 14     Both parents  Post-graduate education
#
#            Family Financial Status Class  Department Perfomance in English  \
# 35  We are financially comfortable   SS3  Humanities             Excellent
#
#    Perfomance in Maths  ... School Learning Resources  \
# 35                Good  ...   Extra tutoring sessions
#
#    Motivation for Attending School Plan to Attend University JAMB Goal Score  \
# 35    To prepare for a good career                       Yes   300 And Above
#
#    Extracurricular Hours                               Free Time Activities  \
# 35     Less than 5 hours  Studying,Socializing with friends,Watching mov...
#
#    Language at Home Involved in Work Outside School Last Exam Performance  \
# 35          English                    Occasionally            70% - 100%
#
#    Foundational Knowledge
# 35                Average
#
# ...

# %%
# Checking the rows to see if the changes were made
print("Department of specified rows:")
for index in indices_to_view:
    if index in df.index:
        print(f"Index {index}: {df.loc[index]}")
    else:
        print(f"Index {index} does not exist in the DataFrame.")
# Out:
# Department of specified rows:
# Index 0: Student ID                                                                      1001
# Gender                                                                        Female
# Age Group                                                                    15 - 16
# Living Situation                                                        Both parents
# Parent Education Level                                       Post-graduate education
# Family Financial Status                  We meet our needs but can't afford luxuries
# Class                                                                            SS2
# Department                                                                   Science
# Perfomance in English                                                      Excellent
# Perfomance in Maths                                                             Good
# Perfomance in Biology                                                      Excellent
# ...

# %% [markdown]
# **SUCCESSFUL**

# %% [markdown]
# CHECKING FOR DUPLICATES
# ***

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %%
# Converting all object columns (except 'Student ID') to category
categorical_columns = df.columns.difference(['Student ID'])

df[categorical_columns] = df[categorical_columns].astype('category')

print(df.dtypes)
# Out:
# Student ID                                  int64
# Gender                                   category
# Age Group                                category
# Living Situation                         category
# Parent Education Level                   category
# Family Financial Status                  category
# Class                                    category
# Department                               category
# Perfomance in English                    category
# Perfomance in Maths                      category
# Perfomance in Biology                    category
# Perfomance in Physics                    category
# Perfomance in Chemistry                  category
# Perfomance in Lit in English             category
# Perfomance in Government                 category
# Perfomance in CRS                        category
# Perfomance in Commerce                   category
# Perfomance in Accounting                 category
# Perfomance in Economics                  category
# ...

# %%
# Checking for the unique values for each categorical column
for col in categorical_columns:
    print(f'Unique values in {col}: {df[col].unique()}')
# Out:
# Unique values in Access to Counseling: ['I'm not sure', 'Yes', 'No']
# Categories (3, object): ['I'm not sure', 'No', 'Yes']
# Unique values in Age Group: ['15 - 16', '12 - 14', '17 - 18']
# Categories (3, object): ['12 - 14', '15 - 16', '17 - 18']
# Unique values in Class: ['SS2', 'SS3', 'SS1']
# Categories (3, object): ['SS1', 'SS2', 'SS3']
# Unique values in Comfort in School Environment: ['Somewhat Comfortable', 'Comfortable', 'Uncomfortable']
# Categories (3, object): ['Comfortable', 'Somewhat Comfortable', 'Uncomfortable']
# Unique values in Confidence in Academic Ability: ['Somewhat confident', 'Not confident', 'Very confident']
# Categories (3, object): ['Not confident', 'Somewhat confident', 'Very confident']
# Unique values in Considered Dropping Out: ['Never', 'Sometimes', 'Often']
# Categories (3, object): ['Never', 'Sometimes', 'Often']
# Unique values in Department: ['Science', 'Commercial', 'Humanities']
# ...

# %% [markdown]
# ### **Checking distributions in the dataset for proper cleaning**
# ***

# %% [markdown]
# Conducting an initial distribution analysis of the dataset. This analysis revealed several discrepancies in some of the columns, which will be addressed to ensure the dataset is clean and ready for `further analysis`.

# %%
# List of columns to skip
columns_to_skip = ['Free Time Activities', 'Home Learning Resources', 'School Learning Resources','Type of Bullying']  # Add other column names as needed

for col in categorical_columns:
    if col not in columns_to_skip:  # Only plot if the column is not in the skip list
        sns.countplot(data=df, x=col)
        plt.title(f'Distribution of {col}')
        plt.xticks(rotation=45)
        plt.show()

# %% [markdown]
# ##### Cleaning the "Age Group" column to standardize inconsistent entries like `15 -16` and `17 -18` for accurate analysis.

# %%
df.sample(3)

# %%
# Standardizing variations by replacing
df['Age Group'] = df['Age Group'].replace({
    '15 -16': '15 - 16',  
    '15 - 16 ': '15 - 16', 
    '17 -18': '17 - 18',
})

print("Unique values in Age Group after cleaning and conversion:", df['Age Group'].unique())

# %% [markdown]
# ##### Cleaning the "Comfort in School Environment" column to standardize inconsistent entries like `Very Comfortable` and `Comfortable` for accurate analysis.

# %%
# Standardizing variations by replacing
df['Comfort in School Environment'] = df['Comfort in School Environment'].replace({
    'Very Comfortable': 'Comfortable'
})

# Printing unique values to verify the category renaming
print("Unique values in Comfort in School Environment after cleaning:", df['Comfort in School Environment'].unique())

# %% [markdown]
# ##### Cleaning the "Confidence in Academic Ability" column to standardize inconsistent entries like `Not very confident` and `Confidence in Academic Ability` for accurate analysis.

# %%
# Replacing the inconsistent entries
df['Confidence in Academic Ability'] = df['Confidence in Academic Ability'].replace({
    'Not very confident': 'Not confident',
    'Confidence in Academic Ability': 'Very confident'
})

df['Confidence in Academic Ability'] = df['Confidence in Academic Ability'].cat.set_categories([
    'Not confident', 
    'Somewhat confident', 
    'Very confident'
])

print("Unique values in Confidence in Academic Ability after cleaning:", df['Confidence in Academic Ability'].unique())

# %% [markdown]
# ##### Cleaning the "Considered Dropping Out" column to standardize inconsistent entries like `Yes` and `Often` for accurate analysis.

# %%
# Replacing 'Yes' with 'Often'
df['Considered Dropping Out'] = df['Considered Dropping Out'].replace('Yes', 'Often')

df['Considered Dropping Out'] = df['Considered Dropping Out'].cat.set_categories([
    'Never', 
    'Sometimes', 
    'Often'
])

print("Unique values in Considered Dropping Out after cleaning:", df['Considered Dropping Out'].unique())

# %% [markdown]
# ##### Cleaning the "Extra Tutoring" column to standardize inconsistent entries like `Yes` and `Regularly` for accurate analysis.

# %%
# Replacing 'Yes' with 'Regularly'
df['Extra Tutoring'] = df['Extra Tutoring'].replace('Yes', 'Regularly')

df['Extra Tutoring'] = df['Extra Tutoring'].cat.set_categories([
    'No', 
    'Occasionally', 
    'Regularly'
])

print("Unique values in Extra Tutoring after cleaning:", df['Extra Tutoring'].unique())

# %% [markdown]
# - Checking the foundational knowledge and previous performance of students who have "Extracurricular Hours" as 10 - 15 hours

# %%
# Filtering the DataFrame for students with 'Extracurricular Hours' as '10 - 15 hours'
filtered_students = df[df['Extracurricular Hours'] == '10 - 15 hours'].count()

foundational_knowledge = filtered_students['Foundational Knowledge']
previous_performance = filtered_students['Last Exam Performance']

print("Foundational Knowledge of students with 10 - 15 hours of Extracurricular Activities:")
print(foundational_knowledge)

print("\nPrevious Performance of students with 10 - 15 hours of Extracurricular Activities:")
print(previous_performance)

# %% [markdown]
# > Just 3 students.

# %% [markdown]
# ##### Cleaning the "Extracurricular Hours" column to standardize inconsistent entries like `10 - 15 hours` to `More than 10 hours`

# %%
# Replacing '10 - 15 hours' with 'More than 10 hours'
df['Extracurricular Hours'] = df['Extracurricular Hours'].replace('10 - 15 hours', 'More than 10 hours')

df['Extracurricular Hours'] = df['Extracurricular Hours'].cat.set_categories([
    'Less than 5 hours', 
    '5 - 10 hours', 
    'More than 10 hours'
])

print("Unique values in Extracurricular Hours after cleaning:", df['Extracurricular Hours'].unique())

# %% [markdown]
# ##### Cleaning the "Family Financial Status" column to standardize inconsistent entries and remove duplicates.
# - Unifying the two entries `We struggle to meet basic needs` into a single, consistent entry.

# %%
# Replacing the inconsistent entries
df['Family Financial Status'] = df['Family Financial Status'].replace(
    {
        'We Struggle to meet basic needs': 'We struggle to meet basic needs'
    }
)

df['Family Financial Status'] = df['Family Financial Status'].cat.set_categories([
    'We meet our needs but can\'t afford luxuries',
    'We can afford some luxuries',
    'We are financially comfortable',
    'We struggle to meet basic needs'
])

print("Unique values in Family Financial Status after cleaning:", df['Family Financial Status'].unique())

# %% [markdown]
# ##### Standardizing the "Foundational Knowledge" column by merging inconsistent entries to improve data accuracy.

# %%
# Cleaning the Foundational Knowledge column by standardizing entries
df['Foundational Knowledge'] = df['Foundational Knowledge'].str.title().replace('Strong', 'Strong')

print("Unique values in Foundational Knowledge after cleaning:", df['Foundational Knowledge'].unique())

# %% [markdown]
# ##### Standardizing the "Involved in Work Outside School" column to ensure consistent responses for accurate analysis.
# - Unifying the two entries `Yes` and `Frequently` into a single response.

# %%
# Cleaning the Involved in Work Outside School column by merging responses
df['Involved in Work Outside School'] = df['Involved in Work Outside School'].replace('Yes', 'Frequently')

print("Unique values in Involved in Work Outside School after cleaning:", df['Involved in Work Outside School'].unique())

# %% [markdown]
# ##### Standardizing the "JAMB Goal Score" column to eliminate duplicate entries for accurate analysis.
# - Merging the entries `300 And Above` and `300 and Above` into a single response

# %%
# Cleaning the JAMB Goal Score column by merging duplicate entries
df['JAMB Goal Score'] = df['JAMB Goal Score'].replace('300 and Above', '300 And Above')

print("Unique values in JAMB Goal Score after cleaning:", df['JAMB Goal Score'].unique())

# %% [markdown]
# ##### Standardizing the "Last Exam Performance" column to unify inconsistent entries for accurate analysis.
# - Change `60% -69%` to `60% - 69%`.
# - Merge `40% - 49%` into `40% - 59%`.

# %%
# Cleaning the Last Exam Performance column by correcting duplicate entries
df['Last Exam Performance'] = df['Last Exam Performance'].replace({
    '60% -69%': '60% - 69%',  # Correcting the formatting
    '40% - 49%': '40% - 59%'   # Merging with the broader category
})

# Check the unique values after cleaning
print("Unique values in Last Exam Performance after cleaning:", df['Last Exam Performance'].unique())
# Out:
# Unique values in Last Exam Performance after cleaning: ['60% - 69%', '70% - 100%', 'Below 40%', '40% - 59%']
# Categories (4, object): ['40% - 59%', '60% - 69%', '70% - 100%', 'Below 40%']

# %% [markdown]
# ##### Renaming the "Perfomance in Commerce" column to "Performance in Commerce" for correct spelling and standardizing inconsistent entries like `Nil` and `NIl` for accurate analysis.

# %%
# Rename the column for correct spelling
df.rename(columns={'Perfomance in Commerce': 'Performance in Commerce'}, inplace=True)

# %%
# Standardizing the entries by replacing 'NIl' with 'Nil'
df['Performance in Commerce'] = df['Performance in Commerce'].replace('NIl', 'Nil')

print("Unique values in Performance in Commerce after cleaning:", df['Performance in Commerce'].unique())
# Out:
# Unique values in Performance in Commerce after cleaning: ['Nil', 'Fair', 'Excellent', 'Good']
# Categories (4, object): ['Excellent', 'Fair', 'Good', 'Nil']

# %% [markdown]
# ##### Changing all column names that start with `Perfomance` to "Performance," along with checking the columns at each step.

# %%
perfomance_columns = [col for col in df.columns if col.startswith('Perfomance')]
print("Columns before renaming:", perfomance_columns)
# Out:
# Columns before renaming: []

# %%
df.rename(columns={col: col.replace('Perfomance', 'Performance') for col in perfomance_columns}, inplace=True)

# %%
updated_perfomance_columns = [col for col in df.columns if col.startswith('Performance')]
print("Columns after renaming:", updated_perfomance_columns)
# Out:
# Columns after renaming: ['Performance in English', 'Performance in Maths', 'Performance in Biology', 'Performance in Physics', 'Performance in Chemistry', 'Performance in Lit in English', 'Performance in Government', 'Performance in CRS', 'Performance in Commerce', 'Performance in Accounting', 'Performance in Economics']

# %% [markdown]
# ##### Cleaning the `Performance in Government` column to standardize inconsistent entries, specifically replacing `M` with `Nil` for accurate analysis.

# %%
# Standardizing the entries in 'Performance in Government' column
df['Performance in Government'] = df['Performance in Government'].replace('M', 'Nil')

# %%
unique_values = df['Performance in Government'].unique()
print("Unique values in Performance in Government after cleaning:", unique_values)
# Out:
# Unique values in Performance in Government after cleaning: ['Nil', 'Good', 'Excellent', 'Fair']
# Categories (4, object): ['Excellent', 'Fair', 'Good', 'Nil']

# %% [markdown]
# ##### Cleaning the `Plan to Attend University` column to standardize inconsistent entries by replacing variations of `Yes` with a single standardized entry for accurate analysis.

# %%
# Standardizing the entries in 'Plan to Attend University' column
df['Plan to Attend University'] = df['Plan to Attend University'].replace({'yes': 'Yes', "I'm not sure": 'Not Sure'})

unique_values = df['Plan to Attend University'].unique()
print("Unique values in Plan to Attend University after cleaning:", unique_values)
# Out:
# Unique values in Plan to Attend University after cleaning: ['Yes', 'Not Sure', 'No']
# Categories (3, object): ['Not Sure', 'No', 'Yes']

# %% [markdown]
# ##### Cleaning the `Stress About Schoolwork1 column to standardize inconsistent entries, merging `Rearly` to `Rarely` and ensuring a consistent set of responses for accurate analysis.

# %%
df['Stress About Schoolwork'] = df['Stress About Schoolwork'].replace({
    'Rearly': 'Rarely',  # Correcting the spelling of 'Rearly' to 'Rarely'
    'Somewhat stressed': 'Sometimes'  # Standardizing 'Somewhat stressed' to 'Sometimes'
})

unique_values = df['Stress About Schoolwork'].unique()
print("Unique values in Stress About Schoolwork after cleaning:", unique_values)
# Out:
# Unique values in Stress About Schoolwork after cleaning: ['Always', 'Sometimes', 'Rarely', 'Never']
# Categories (4, object): ['Always', 'Never', 'Rarely', 'Sometimes']

# %% [markdown]
# ##### Cleaning the `Study Hours per Week` column to consolidate overlapping categories and ensure consistency for accurate analysis.

# %%
df['Study Hours per Week'] = df['Study Hours per Week'].replace({
    '10 - 15 hours': 'More than 10 hours',  # Consolidating '10 - 15 hours' into 'More than 10 hours'
})

unique_values = df['Study Hours per Week'].unique()
print("Unique values in Study Hours per Week after cleaning:", unique_values)
# Out:
# Unique values in Study Hours per Week after cleaning: ['Less than 5 hours', '5 - 10 hours', 'More than 10 hours', 'More than 15 hours']
# Categories (4, object): ['5 - 10 hours', 'Less than 5 hours', 'More than 10 hours', 'More than 15 hours']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns to skip
columns_to_skip = ['Free Time Activities', 'Home Learning Resources', 'School Learning Resources', 'Type of Bullying'] 
# Print the actual column names in the DataFrame
print("Available columns:", df.columns.tolist())  

for col in categorical_columns:
    if col not in columns_to_skip:  # Only plot if the column is not in the skip list
        if col in df.columns:  # Check if the column exists in the DataFrame
            sns.countplot(data=df, x=col)
            plt.title(f'Distribution of {col}')
            plt.xticks(rotation=45)
            plt.show()
        else:
            print(f"Column '{col}' does not exist in the DataFrame.")  # Debugging message
# Out:
# Available columns: ['Student ID', 'Gender', 'Age Group', 'Living Situation', 'Parent Education Level', 'Family Financial Status', 'Class', 'Department', 'Performance in English', 'Performance in Maths', 'Performance in Biology', 'Performance in Physics', 'Performance in Chemistry', 'Performance in Lit in English', 'Performance in Government', 'Performance in CRS', 'Performance in Commerce', 'Performance in Accounting', 'Performance in Economics', 'Study Hours per Week', 'Extra Tutoring', 'School Attendance', 'Extracurricular Participation', 'Considered Dropping Out', 'Reason To Dropout', 'Experienced Bullying', 'Type of Bullying', 'Comfort in School Environment', 'Trusted Teacher', 'Peer Pressure', 'Parents Help with Homework', 'Parents Attend Parent-Teacher Meeting', 'Parents Encourage Higher Education', 'Stress About Schoolwork', 'Confidence in Academic Ability', 'Access to Counseling', 'Home Learning Resources', 'School Learning Resources', 'Motivation for Attending School', 'Plan
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
columns_of_interest = [
    'Student ID', 'Gender', 'Age Group', 'Living Situation', 
    'Parent Education Level', 'Family Financial Status', 
    'Class', 'Department', 
    'Performance in English', 'Performance in Maths', 
    'Performance in Biology', 'Performance in Physics', 
    'Performance in Chemistry', 'Performance in Lit in English', 
    'Performance in Government', 'Performance in CRS', 
    'Performance in Commerce', 'Performance in Accounting', 
    'Performance in Economics', 'Study Hours per Week', 
    'Extra Tutoring', 'School Attendance', 
    'Extracurricular Participation', 'Considered Dropping Out', 
    'Reason To Dropout', 'Experienced Bullying', 
    'Type of Bullying', 'Comfort in School Environment', 
    'Trusted Teacher', 'Peer Pressure', 
    'Parents Help with Homework', 'Parents Attend Parent-Teacher Meeting', 
    'Parents Encourage Higher Education', 
    'Stress About Schoolwork', 'Confidence in Academic Ability', 
    'Access to Counseling', 'Home Learning Resources', 
    'School Learning Resources', 'Motivation for Attending School', 
    'Plan to Attend University', 'JAMB Goal Score', 
    'Extracurricular Hours', 'Free Time Activities', 
    'Language at Home', 'Involved in Work Outside School', 
    'Last Exam Performance', 'Foundational Knowledge'
]

# Create a dictionary to store unique values for each column
unique_values = {col: df[col].unique() for col in columns_of_interest}

# Display the unique values for each column
for col, unique_vals in unique_values.items():
    print(f"Unique values in '{col}':\n{unique_vals}\n")
# Out:
# Unique values in 'Student ID':
# [1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014
#  1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028
#  1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041 1042
#  1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055 1056
#  1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068 1069 1070
#  1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082 1083 1084
#  1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096 1097 1098
#  1099 1100]
#
# Unique values in 'Gender':
# ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']
#
# Unique values in 'Age Group':
# ['15 - 16', '12 - 14', '17 - 18']
# Categories (3, object): ['12 - 14', '15 - 16', '17 - 18']
#
# Unique values in 'Living Situation':
# ['Both parents', 'Single parent', 'Guardian']
# Categories (3, object): ['Both parents', 'Guardian', 'Single parent']
#
# Unique values in 'Parent Education Level':
# ...

# %%
# Save the dataset as an Excel file
file_name = '../data/processed_survey_data.xlsx'
df.to_excel(file_name, index=False)

print(f"Data has been saved at {file_name}")
# Out:
# Data has been saved at ../data/processed_survey_data.xlsx

# %%
df.to_csv('../data/processed_survey_data.csv', index=False)

# %% [markdown]
# # Data Cleaning Summary
#
# We identified rows where the performance metrics were marked as `Nil`.
# ### Replacement Logic
# For the identified rows and columns, we implemented a replacement logic to fill the `Nil` values with one of the following possible performance ratings after reviewing the questionnaire:
# - **Good**
# - **Excellent**
# - **Fair**
# - **Poor**
#
# In this project, a thorough cleaning and standardization process was undertaken to ensure data consistency and accuracy for analysis. The following changes were made:
#
# 1. **Confidence in Academic Ability**
#    - Changed `Not very confident` to `Not confident`
#    - Renamed `Confidence in Academic Ability` to `Very confident`
#    - Unique Values After Cleaning: `['Somewhat confident', 'Very confident', 'Not confident']`
#
# 2. **Considered Dropping Out**
#    - Consolidated `Yes` into `Often`
#    - Unique Values After Cleaning: `['Never', 'Sometimes', 'Often']`
#
# 3. **Extra Tutoring**
#    - Changed `Yes` to `Regularly`
#    - Unique Values After Cleaning: `['No', 'Occasionally', 'Regularly']`
#
# 4. **Extracurricular Hours**
#    - Changed `0 - 15 hours` to `More than 10 hours`
#    - Unique Values After Cleaning: `['Less than 5 hours', '5 - 10 hours', 'More than 10 hours']`
#
# 5. **Family Financial Status**
#    - Standardized duplicate entries of `We struggle to meet basic needs` to a single entry.
#    - Unique Values After Cleaning: `['We meet our needs but can't afford luxuries', 'We can afford some luxuries', 'We are financially comfortable', 'We struggle to meet basic needs']`
#
# 6. **Foundational Knowledge**
#    - Changed `strong` to `Strong`.
#    - Unique Values After Cleaning: `['Average', 'Strong', 'Weak']`
#
# 7. **Involved in Work Outside School**
#    - Consolidated unique values to ensure consistent representation.
#    - Unique Values After Cleaning: `['Frequently', 'Occasionally', 'No', 'Yes']`
#
# 8. **JAMB Goal Score**
#    - Standardized the format of score ranges for clarity.
#    - Unique Values After Cleaning: `['200 To 250', '250 To 300', '300 And Above', 'Below 200']`
#
# 9. **Last Exam Performance**
#    - Consolidated duplicate categories and corrected range inconsistencies.
#    - Unique Values After Cleaning: `['60% - 69%', '70% - 100%', 'Below 40%', '40% - 59%']`
#
# 10. **Performance in Commerce**
#     - Corrected spelling of `Perfomance` to `Performance`.
#     - Replaced duplicate values of `NIl` with `Nil`.
#     - Unique Values After Cleaning: `['Nil', 'Fair', 'Excellent', 'Good']`
#
# 11. **Performance in Government**
#     - Corrected spelling of `Perfomance` to `Performance`.
#     - Unique Values After Cleaning: `['Nil', 'Good', 'Excellent', 'Fair', 'M']`
#
# 12. **Plan to Attend University**
#     - Standardized entries from mixed cases.
#     - Unique Values After Cleaning: `['Yes', "I'm not sure", 'No']`
#
# 13. **Stress About Schoolwork**
#     - Corrected `Rearly` to `Rarely`.
#     - Unique Values After Cleaning: `['Always', 'Sometimes', 'Rarely', 'Never', 'Somewhat stressed']`
#
# 14. **Study Hours per Week**
#     - Consolidated overlapping categories by changing `10 - 15 hours` to `More than 10 hours`.
#     - Unique Values After Cleaning: `['Less than 5 hours', '5 - 10 hours', 'More than 10 hours']`
#
# These changes enhance the dataset's clarity, allowing for more accurate analysis and interpretation.
