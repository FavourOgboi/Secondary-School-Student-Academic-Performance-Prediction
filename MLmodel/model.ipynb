# %%
import pandas as pd
from sqlalchemy import create_engine, inspect,text
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Database path in the schema folder
db_path = '../Schema/student_database.db'

engine = create_engine(f'sqlite:///{db_path}')

with engine.connect() as conn:
    print("Connected to the database.")
    
    inspector = inspect(engine)
    tables = inspector.get_table_names()
    print("Tables in the database:", tables)
# Out:
# Connected to the database.
# Tables in the database: ['student_performance']

# %%
query = "SELECT * FROM student_performance;"
df = pd.read_sql(query, con=engine)
df.head()
# Out:
#    Student ID  Gender Age Group Living Situation   Parent Education Level  \
# 0        1001  Female   15 - 16     Both parents  Post-graduate education
# 1        1002  Female   15 - 16     Both parents         Higher Education
# 2        1003    Male   15 - 16     Both parents  Post-graduate education
# 3        1004    Male   12 - 14     Both parents         Higher Education
# 4        1005    Male   15 - 16    Single parent         Higher Education
#
#                        Family Financial Status Class Department  \
# 0  We meet our needs but can't afford luxuries   SS2    Science
# 1                  We can afford some luxuries   SS3    Science
# 2  We meet our needs but can't afford luxuries   SS3    Science
# 3                  We can afford some luxuries   SS3    Science
# 4               We are financially comfortable   SS3    Science
#
#   Performance in English Performance in Maths  ...  \
# 0              Excellent                 Good  ...
# 1                   Good                 Good  ...
# 2                   Fair                 Fair  ...
# 3                   Good            Excellent  ...
# 4                   Good                 Fair  ...
#
#                School Learning Resources Motivation for Attending School  \
# 0                                Library     To learn and gain knowledge
# 1                                Library    To prepare for a good career
# 2                                    Nil    To prepare for a good career
# 3  Computer lab, Extra tutoring sessions     To learn and gain knowledge
# 4  Computer lab, Extra tutoring sessions    To prepare for a good career
#
#   Plan to Attend University JAMB Goal Score Extracurricular Hours  \
# 0                       Yes      200 To 250     Less than 5 hours
# 1                       Yes   300 And Above          5 - 10 hours
# 2                  Not Sure      200 To 250    More than 10 hours
# 3                       Yes   300 And Above     Less than 5 hours
# 4                       Yes      200 To 250     Less than 5 hours
#
#                                 Free Time Activities Language at Home  \
# 0                               Doing chores at home           Yoruba
# 1                                             Others           Yoruba
# 2                                     Playing sports          English
# 3  Studying,Socializing with friends,Watching mov...          English
# 4  Watching movies,Playing sports,Doing chores at...          English
#
#   Involved in Work Outside School Last Exam Performance Foundational Knowledge
# 0                      Frequently             60% - 69%                Average
# 1                    Occasionally            70% - 100%                 Strong
# 2                              No             60% - 69%                Average
# 3                              No            70% - 100%                Average
# 4                              No             60% - 69%                 Strong
#
# [5 rows x 47 columns]

# %%
df.shape
# Out:
# (100, 47)

# %%
df['Last Exam Performance']
# Out:
# 0      60% - 69%
# 1     70% - 100%
# 2      60% - 69%
# 3     70% - 100%
# 4      60% - 69%
#          ...
# 95     60% - 69%
# 96    70% - 100%
# 97     40% - 59%
# 98     60% - 69%
# 99     60% - 69%
# Name: Last Exam Performance, Length: 100, dtype: object

# %%
# To categorize new performance column into Likely to Succeed or Likely to Fail based on last performance

df['Next Exam Prediction'] = None  # Initialize the column with None or empty values

# Update based on conditions using loc[]
df.loc[df['Last Exam Performance'] == 'Below 40%', 'Next Exam Prediction'] = 'Likely To Fail'
df.loc[df['Last Exam Performance'] == '40% To 59%', 'Next Exam Prediction'] = 'Likely To Fail'
df.loc[df['Last Exam Performance'] == '60% - 69%', 'Next Exam Prediction'] = 'Likely To Succeed'
df.loc[df['Last Exam Performance'] == '70% - 100%', 'Next Exam Prediction'] = 'Likely to Succeed'

# Display the updated DataFrame
df
# Out:
#     Student ID  Gender Age Group Living Situation   Parent Education Level  \
# 0         1001  Female   15 - 16     Both parents  Post-graduate education
# 1         1002  Female   15 - 16     Both parents         Higher Education
# 2         1003    Male   15 - 16     Both parents  Post-graduate education
# 3         1004    Male   12 - 14     Both parents         Higher Education
# 4         1005    Male   15 - 16    Single parent         Higher Education
# ..         ...     ...       ...              ...                      ...
# 95        1096  Female   15 - 16     Both parents         Higher Education
# 96        1097    Male   15 - 16     Both parents         Secondary school
# 97        1098  Female   15 - 16    Single parent         Secondary school
# 98        1099    Male   15 - 16     Both parents         Higher Education
# 99        1100  Female   12 - 14         Guardian         Secondary school
#
#                         Family Financial Status Class  Department  \
# 0   We meet our needs but can't afford luxuries   SS2     Science
# 1                   We can afford some luxuries   SS3     Science
# 2   We meet our needs but can't afford luxuries   SS3     Science
# 3                   We can afford some luxuries   SS3     Science
# 4                We are financially comfortable   SS3     Science
# ..                                          ...   ...         ...
# 95                  We can afford some luxuries   SS2  Humanities
# 96  We meet our needs but can't afford luxuries   SS1  Humanities
# 97  We meet our needs but can't afford luxuries   SS2  Humanities
# 98                  We can afford some luxuries   SS1  Humanities
# 99              We struggle to meet basic needs   SS1  Humanities
#
#    Performance in English Performance in Maths  ...  \
# 0               Excellent                 Good  ...
# 1                    Good                 Good  ...
# 2                    Fair                 Fair  ...
# 3                    Good            Excellent  ...
# 4                    Good                 Fair  ...
# ..                    ...                  ...  ...
# 95                   Good                 Good  ...
# 96              Excellent                 Fair  ...
# 97                   Fair                 Fair  ...
# 98                   Good                 Good  ...
# 99                   Fair                 Poor  ...
#
#    Motivation for Attending School Plan to Attend University JAMB Goal Score  \
# 0      To learn and gain knowledge                       Yes      200 To 250
# 1     To prepare for a good career                       Yes   300 And Above
# 2     To prepare for a good career                  Not Sure      200 To 250
# 3      To learn and gain knowledge                       Yes   300 And Above
# 4     To prepare for a good career                       Yes      200 To 250
# ..                             ...                       ...             ...
# 95     To learn and gain knowledge                       Yes      250 To 300
# 96     To learn and gain knowledge                       Yes      250 To 300
# 97     To learn and gain knowledge                       Yes      200 To 250
# 98     To learn and gain knowledge                       Yes      200 To 250
# 99     To learn and gain knowledge                       Yes      200 To 250
#
#    Extracurricular Hours                               Free Time Activities  \
# 0      Less than 5 hours                               Doing chores at home
# 1           5 - 10 hours                                             Others
# 2     More than 10 hours                                     Playing sports
# 3      Less than 5 hours  Studying,Socializing with friends,Watching mov...
# 4      Less than 5 hours  Watching movies,Playing sports,Doing chores at...
# ..                   ...                                                ...
# 95          5 - 10 hours                               Doing chores at home
# 96     Less than 5 hours                                    Watching movies
# 97     Less than 5 hours                                           Studying
# 98     Less than 5 hours                               Doing chores at home
# 99     Less than 5 hours                                     Playing sports
#
#    Language at Home Involved in Work Outside School Last Exam Performance  \
# 0            Yoruba                      Frequently             60% - 69%
# 1            Yoruba                    Occasionally            70% - 100%
# 2           English                              No             60% - 69%
# 3           English                              No            70% - 100%
# 4           English                              No             60% - 69%
# ..              ...                             ...                   ...
# 95          English                              No             60% - 69%
# 96          English                              No            70% - 100%
# 97             Igbo                              No             40% - 59%
# 98          English                      Frequently             60% - 69%
# 99             Igbo                              No             60% - 69%
#
#    Foundational Knowledge Next Exam Prediction
# 0                 Average    Likely To Succeed
# 1                  Strong    Likely to Succeed
# 2                 Average    Likely To Succeed
# 3                 Average    Likely to Succeed
# 4                  Strong    Likely To Succeed
# ..                    ...                  ...
# 95                Average    Likely To Succeed
# 96                Average    Likely to Succeed
# 97                   Weak                 None
# 98                 Strong    Likely To Succeed
# 99                Average    Likely To Succeed
#
# [100 rows x 48 columns]

# %%
df.shape
# Out:
# (100, 48)

# %%
from sklearn.model_selection import train_test_split

# Splitting 70% for training and 30% for temp (validation + testing)
train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42)

val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Check the number of rows in each set
print(f"Training set: {len(train_df)} rows")
print(f"Validation set: {len(val_df)} rows")
print(f"Test set: {len(test_df)} rows")
# Out:
# Training set: 70 rows
# Validation set: 15 rows
# Test set: 15 rows

# %% [markdown]
# ## Identifying Input and Target Columns:

# %%
input_cols = [
    "Age Group",
    "Living Situation",
    "Parent Education Level",
    "Family Financial Status",
    "Class",
    "Department",
    "Performance in English",
    "Performance in Maths",
    "Study Hours per Week",
    "Extra Tutoring",
    "School Attendance",
    "Extracurricular Participation",
    "Considered Dropping Out",
    "Experienced Bullying",
    "Comfort in School Environment",
    "Stress About Schoolwork",
    "Confidence in Academic Ability",
    "Access to Counseling",
    "Motivation for Attending School",
    "Plan to Attend University",
    "JAMB Goal Score",
    "Foundational Knowledge",
    "Last Exam Performance"
]

# %%
input_cols = input_cols
target_col = "Next Exam Prediction"

# %% [markdown]
# Creating inputs and targets for the training, validation and test sets for further processing and model training.

# %%
train_inputs = train_df[input_cols].copy()
train_targets = train_df[target_col].copy()

# %%
val_inputs = val_df[input_cols].copy()
val_targets = val_df[target_col].copy()

# %%
test_inputs = test_df[input_cols].copy()
test_targets = test_df[target_col].copy()

# %%
train_inputs.sample(5)
# Out:
#    Age Group Living Situation   Parent Education Level  \
# 41   15 - 16     Both parents         Secondary school
# 61   15 - 16     Both parents  Post-graduate education
# 38   15 - 16     Both parents  Post-graduate education
# 97   15 - 16    Single parent         Secondary school
# 87   15 - 16     Both parents         Secondary school
#
#                         Family Financial Status Class  Department  \
# 41  We meet our needs but can't afford luxuries   SS2  Commercial
# 61               We are financially comfortable   SS3     Science
# 38                  We can afford some luxuries   SS2  Humanities
# 97  We meet our needs but can't afford luxuries   SS2  Humanities
# 87  We meet our needs but can't afford luxuries   SS1     Science
#
#    Performance in English Performance in Maths Study Hours per Week  \
# 41                   Good                 Fair    Less than 5 hours
# 61                   Fair            Excellent         5 - 10 hours
# 38              Excellent                 Poor    Less than 5 hours
# 97                   Fair                 Fair    Less than 5 hours
# 87                   Good                 Fair    Less than 5 hours
#
#    Extra Tutoring  ... Experienced Bullying Comfort in School Environment  \
# 41             No  ...         Occasionally          Somewhat Comfortable
# 61   Occasionally  ...                Never                   Comfortable
# 38   Occasionally  ...                Never          Somewhat Comfortable
# 97             No  ...                Never          Somewhat Comfortable
# 87      Regularly  ...           Frequently                   Comfortable
#
#    Stress About Schoolwork Confidence in Academic Ability  \
# 41               Sometimes             Somewhat confident
# 61               Sometimes                 Very confident
# 38               Sometimes                  Not confident
# 97               Sometimes             Somewhat confident
# 87               Sometimes             Somewhat confident
#
#    Access to Counseling Motivation for Attending School  \
# 41         I'm not sure    To avoid being bored at home
# 61         I'm not sure     To learn and gain knowledge
# 38         I'm not sure    To prepare for a good career
# 97                   No     To learn and gain knowledge
# 87                  Yes     To learn and gain knowledge
#
#    Plan to Attend University JAMB Goal Score Foundational Knowledge  \
# 41                       Yes      250 To 300                   Weak
# 61                       Yes   300 And Above                 Strong
# 38                       Yes   300 And Above                 Strong
# 97                       Yes      200 To 250                   Weak
# 87                       Yes      250 To 300                Average
#
#    Last Exam Performance
# 41             40% - 59%
# 61            70% - 100%
# 38             60% - 69%
# 97             40% - 59%
# 87             40% - 59%
#
# [5 rows x 23 columns]

# %%
train_targets
# Out:
# 11    Likely To Succeed
# 47    Likely to Succeed
# 85    Likely To Succeed
# 28    Likely To Succeed
# 93    Likely to Succeed
#             ...
# 60                 None
# 71    Likely To Succeed
# 14    Likely to Succeed
# 92    Likely to Succeed
# 51    Likely to Succeed
# Name: Next Exam Prediction, Length: 70, dtype: object

# %% [markdown]
# Identifing which of the columns are numerical and which ones are categorical

# %%
import numpy as np
numeric_cols = train_inputs.select_dtypes(include=np.number).columns.tolist()
categorical_cols = train_inputs.select_dtypes('object').columns.tolist()

# %%
numeric_cols
# Out:
# []

# %% [markdown]
# No  Numeric Cols

# %%
categorical_cols
# Out:
# ['Age Group',
#  'Living Situation',
#  'Parent Education Level',
#  'Family Financial Status',
#  'Class',
#  'Department',
#  'Performance in English',
#  'Performance in Maths',
#  'Study Hours per Week',
#  'Extra Tutoring',
#  'School Attendance',
#  'Extracurricular Participation',
#  'Considered Dropping Out',
#  'Experienced Bullying',
#  'Comfort in School Environment',
#  'Stress About Schoolwork',
#  'Confidence in Academic Ability',
#  'Access to Counseling',
#  'Motivation for Attending School',
#  'Plan to Attend University',
#  'JAMB Goal Score',
#  'Foundational Knowledge',
#  'Last Exam Performance']

# %%
train_inputs[categorical_cols].nunique()
# Out:
# Age Group                          3
# Living Situation                   3
# Parent Education Level             5
# Family Financial Status            4
# Class                              3
# Department                         3
# Performance in English             3
# Performance in Maths               4
# Study Hours per Week               4
# Extra Tutoring                     3
# School Attendance                  3
# Extracurricular Participation      3
# Considered Dropping Out            3
# Experienced Bullying               3
# Comfort in School Environment      3
# Stress About Schoolwork            4
# Confidence in Academic Ability     3
# Access to Counseling               3
# Motivation for Attending School    5
# Plan to Attend University          3
# JAMB Goal Score                    3
# Foundational Knowledge             3
# Last Exam Performance              4
# dtype: int64

# %% [markdown]
# Encoding Categorical Data

# %%
from sklearn.preprocessing import OneHotEncoder

# Using sparse_output instead of sparse
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder.fit(df[categorical_cols])
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
encoder.categories_
# Out:
# [array(['12 - 14', '15 - 16', '17 - 18'], dtype=object),
#  array(['Both parents', 'Guardian', 'Single parent'], dtype=object),
#  array(['Higher Education', 'No formal education',
#         'Post-graduate education', 'Primary school', 'Secondary school'],
#        dtype=object),
#  array(['We are financially comfortable', 'We can afford some luxuries',
#         "We meet our needs but can't afford luxuries",
#         'We struggle to meet basic needs'], dtype=object),
#  array(['SS1', 'SS2', 'SS3'], dtype=object),
#  array(['Commercial', 'Humanities', 'Science'], dtype=object),
#  array(['Excellent', 'Fair', 'Good'], dtype=object),
#  array(['Excellent', 'Fair', 'Good', 'Poor'], dtype=object),
#  array(['5 - 10 hours', 'Less than 5 hours', 'More than 10 hours',
#         'More than 15 hours'], dtype=object),
#  array(['No', 'Occasionally', 'Regularly'], dtype=object),
#  array(['Every day', 'Most days', 'Occasionally'], dtype=object),
#  array(['Not at all', 'Occasionally', 'Regularly'], dtype=object),
#  array(['Never', 'Often', 'Sometimes'], dtype=object),
#  array(['Frequently', 'Never', 'Occasionally'], dtype=object),
#  array(['Comfortable', 'Somewhat Comfortable', 'Uncomfortable'],
#        dtype=object),
#  array(['Always', 'Never', 'Rarely', 'Sometimes'], dtype=object),
#  array(['Not confident', 'Somewhat confident', 'Very confident'],
#        dtype=object),
#  array(["I'm not sure", 'No', 'Yes'], dtype=object),
#  array(['Others', 'To avoid being bored at home',
#         'To learn and gain knowledge', 'To meet family expectations',
#         'To prepare for a good career'], dtype=object),
#  array(['No', 'Not Sure', 'Yes'], dtype=object),
#  array(['200 To 250', '250 To 300', '300 And Above', 'Below 200'],
#        dtype=object),
#  array(['Average', 'Strong', 'Weak'], dtype=object),
#  array(['40% - 59%', '60% - 69%', '70% - 100%', 'Below 40%'], dtype=object)]

# %%
# We can generate column names for each individual category using get_feature_names_out.

encoded_cols = list(encoder.get_feature_names_out(categorical_cols))
print(encoded_cols)
# Out:
# ['Age Group_12 - 14', 'Age Group_15 - 16', 'Age Group_17 - 18', 'Living Situation_Both parents', 'Living Situation_Guardian', 'Living Situation_Single parent', 'Parent Education Level_Higher Education', 'Parent Education Level_No formal education', 'Parent Education Level_Post-graduate education', 'Parent Education Level_Primary school', 'Parent Education Level_Secondary school', 'Family Financial Status_We are financially comfortable', 'Family Financial Status_We can afford some luxuries', "Family Financial Status_We meet our needs but can't afford luxuries", 'Family Financial Status_We struggle to meet basic needs', 'Class_SS1', 'Class_SS2', 'Class_SS3', 'Department_Commercial', 'Department_Humanities', 'Department_Science', 'Performance in English_Excellent', 'Performance in English_Fair', 'Performance in English_Good', 'Performance in Maths_Excellent', 'Performance in Maths_Fair', 'Performance in Maths_Good', 'Performance in Maths_Poor', 'Study Hours per Week_5 - 10 hours', 'Study Hours per Week_Less than 5 hours', 'Study Hours per Week_More than 10 hours', 'Study Hours per Week_More than 15 hours', 'Extra Tutoring_No', 'Extra Tutoring_Occasionally', 'Extra Tutoring_Regularly', 'School Attendance_Every day', 'School Attendance_Most days', 'School Attendance_Occasionally', 'Extracurricular Participation_Not at all', 'Extracurricular Participation_Occasionally', 'Extracurricular Participation_Regularly', 'Considered Dropping Out_Never', 'Considered Dropping Out_Often', 'Considered Dropping Out_Sometimes', 'Experienced Bullying_Frequently', 'Experienced Bullying_Never', 'Experienced Bullying_Occasionally', 'Comfort in School Environment_Comfortable', 'Comfort in School Environment_Somewhat Comfortable', 'Comfort in School Environment_Uncomfortable', 'Stress About Schoolwork_Always', 'Stress About Schoolwork_Never', 'Stress About Schoolwork_Rarely', 'Stress About Schoolwork_Sometimes', 'Confidence in Academic Ability_Not confident', 'Confidence in Academic Ability_Somewhat confident', 'Confidence in Academic Ability_Very confident', "Access to Counseling_I'm not sure", 'Access to Counseling_No', 'Access to Counseling_Yes', 'Motivation for Attending School_Others', 'Motivation for Attending School_To avoid being bored at home', 'Motivation for Attending School_To learn and gain knowledge', 'Motivation for Attending School_To meet family expectations', 'Motivation for Attending School_To prepare for a good career', 'Plan to Attend University_No', 'Plan to Attend University_Not Sure', 'Plan to Attend University_Yes', 'JAMB Goal Score_200 To 250', 'JAMB Goal Score_250 To 300', 'JAMB Goal Score_300 And Above', 'JAMB Goal Score_Below 200', 'Foundational Knowledge_Average', 'Foundational Knowledge_Strong', 'Foundational Knowledge_Weak', 'Last Exam Performance_40% - 59%', 'Last Exam Performance_60% - 69%', 'Last Exam Performance_70% - 100%', 'Last Exam Performance_Below 40%']

# %%
# All of the above columns will be added to train_inputs, val_inputs and test_inputs.

# To perform the encoding, we use the transform method of encoder.

train_inputs[encoded_cols] = encoder.transform(train_inputs[categorical_cols])
val_inputs[encoded_cols] = encoder.transform(val_inputs[categorical_cols])
test_inputs[encoded_cols] = encoder.transform(test_inputs[categorical_cols])
# verifing that these new columns have been added to our training, test and validation sets.

pd.set_option('display.max_columns', None)

test_inputs.head()
# Out:
# (15, 102)

# %%
# Saving Processed Data to Disk

print('train_inputs:', train_inputs.shape)
print('train_targets:', train_targets.shape)
print('val_inputs:', val_inputs.shape)
print('val_targets:', val_targets.shape)
print('test_inputs:', test_inputs.shape)
print('test_targets:', test_targets.shape)
# Out:
# train_inputs: (70, 102)
# train_targets: (70,)
# val_inputs: (15, 102)
# val_targets: (15,)
# test_inputs: (15, 102)
# test_targets: (15,)

# %%
# !pip install pyarrow --quiet

train_inputs.to_parquet('train_inputs.parquet')
val_inputs.to_parquet('val_inputs.parquet')
test_inputs.to_parquet('test_inputs.parquet')

# %%
# %%time
pd.DataFrame(train_targets).to_parquet('train_targets.parquet')
pd.DataFrame(val_targets).to_parquet('val_targets.parquet')
pd.DataFrame(test_targets).to_parquet('test_targets.parquet')
# Out:
# CPU times: total: 46.9 ms
# Wall time: 445 ms

# %%
# Can read the data back using pd.read_parquet.
train_inputs = pd.read_parquet('train_inputs.parquet')
val_inputs = pd.read_parquet('val_inputs.parquet')
test_inputs = pd.read_parquet('test_inputs.parquet')

train_targets = pd.read_parquet('train_targets.parquet')[target_col]
val_targets = pd.read_parquet('val_targets.parquet')[target_col]
test_targets = pd.read_parquet('test_targets.parquet')[target_col]

# %%
# verifying that the data was loaded properly.

print('train_inputs:', train_inputs.shape)
print('train_targets:', train_targets.shape)
print('val_inputs:', val_inputs.shape)
print('val_targets:', val_targets.shape)
print('test_inputs:', test_inputs.shape)
print('test_targets:', test_targets.shape)
# Out:
# train_inputs: (70, 102)
# train_targets: (70,)
# val_inputs: (15, 102)
# val_targets: (15,)
# test_inputs: (15, 102)
# test_targets: (15,)

# %%
val_inputs.sample(3)
# Out:
#    Age Group Living Situation   Parent Education Level  \
# 40   12 - 14     Both parents  Post-graduate education
# 45   15 - 16     Both parents         Higher Education
# 72   15 - 16     Both parents         Higher Education
#
#                         Family Financial Status Class  Department  \
# 40               We are financially comfortable   SS1     Science
# 45  We meet our needs but can't afford luxuries   SS2  Humanities
# 72  We meet our needs but can't afford luxuries   SS3  Commercial
#
#    Performance in English Performance in Maths Study Hours per Week  \
# 40              Excellent            Excellent   More than 10 hours
# 45              Excellent                 Good         5 - 10 hours
# 72              Excellent                 Poor    Less than 5 hours
#
#    Extra Tutoring School Attendance Extracurricular Participation  \
# 40      Regularly         Every day                  Occasionally
# 45      Regularly         Every day                     Regularly
# 72      Regularly         Every day                     Regularly
#
#    Considered Dropping Out Experienced Bullying Comfort in School Environment  \
# 40                   Never         Occasionally                   Comfortable
# 45                   Never           Frequently                   Comfortable
# 72                   Never                Never                   Comfortable
#
#    Stress About Schoolwork Confidence in Academic Ability  \
# 40               Sometimes                 Very confident
# 45                  Always                 Very confident
# 72               Sometimes                  Not confident
#
#    Access to Counseling Motivation for Attending School  \
# 40                  Yes    To prepare for a good career
# 45                  Yes     To learn and gain knowledge
# 72         I'm not sure     To learn and gain knowledge
#
#    Plan to Attend University JAMB Goal Score Foundational Knowledge  \
# 40                       Yes   300 And Above                 Strong
# 45                       Yes      250 To 300                 Strong
# 72                       Yes      250 To 300                 Strong
#
#    Last Exam Performance  Age Group_12 - 14  Age Group_15 - 16  \
# 40            70% - 100%                1.0                0.0
# 45            70% - 100%                0.0                1.0
# 72            70% - 100%                0.0                1.0
#
#     Age Group_17 - 18  Living Situation_Both parents  \
# 40                0.0                            1.0
# 45                0.0                            1.0
# 72                0.0                            1.0
#
#     Living Situation_Guardian  Living Situation_Single parent  \
# 40                        0.0                             0.0
# 45                        0.0                             0.0
# 72                        0.0                             0.0
#
#     Parent Education Level_Higher Education  \
# 40                                      0.0
# 45                                      1.0
# 72                                      1.0
#
#     Parent Education Level_No formal education  \
# 40                                         0.0
# 45                                         0.0
# 72                                         0.0
#
#     Parent Education Level_Post-graduate education  \
# 40                                             1.0
# 45                                             0.0
# 72                                             0.0
#
#     Parent Education Level_Primary school  \
# 40                                    0.0
# 45                                    0.0
# 72                                    0.0
#
#     Parent Education Level_Secondary school  \
# 40                                      0.0
# 45                                      0.0
# 72                                      0.0
#
#     Family Financial Status_We are financially comfortable  \
# 40                                                1.0
# 45                                                0.0
# 72                                                0.0
#
#     Family Financial Status_We can afford some luxuries  \
# 40                                                0.0
# 45                                                0.0
# 72                                                0.0
#
#     Family Financial Status_We meet our needs but can't afford luxuries  \
# 40                                                0.0
# 45                                                1.0
# 72                                                1.0
#
#     Family Financial Status_We struggle to meet basic needs  Class_SS1  \
# 40                                                0.0              1.0
# 45                                                0.0              0.0
# 72                                                0.0              0.0
#
#     Class_SS2  Class_SS3  Department_Commercial  Department_Humanities  \
# 40        0.0        0.0                    0.0                    0.0
# 45        1.0        0.0                    0.0                    1.0
# 72        0.0        1.0                    1.0                    0.0
#
#     Department_Science  Performance in English_Excellent  \
# 40                 1.0                               1.0
# 45                 0.0                               1.0
# 72                 0.0                               1.0
#
#     Performance in English_Fair  Performance in English_Good  \
# 40                          0.0                          0.0
# 45                          0.0                          0.0
# 72                          0.0                          0.0
#
#     Performance in Maths_Excellent  Performance in Maths_Fair  \
# 40                             1.0                        0.0
# 45                             0.0                        0.0
# 72                             0.0                        0.0
#
#     Performance in Maths_Good  Performance in Maths_Poor  \
# 40                        0.0                        0.0
# 45                        1.0                        0.0
# 72                        0.0                        1.0
#
#     Study Hours per Week_5 - 10 hours  Study Hours per Week_Less than 5 hours  \
# 40                                0.0                                     0.0
# 45                                1.0                                     0.0
# 72                                0.0                                     1.0
#
#     Study Hours per Week_More than 10 hours  \
# 40                                      1.0
# 45                                      0.0
# 72                                      0.0
#
#     Study Hours per Week_More than 15 hours  Extra Tutoring_No  \
# 40                                      0.0                0.0
# 45                                      0.0                0.0
# 72                                      0.0                0.0
#
#     Extra Tutoring_Occasionally  Extra Tutoring_Regularly  \
# 40                          0.0                       1.0
# 45                          0.0                       1.0
# 72                          0.0                       1.0
#
#     School Attendance_Every day  School Attendance_Most days  \
# 40                          1.0                          0.0
# 45                          1.0                          0.0
# 72                          1.0                          0.0
#
#     School Attendance_Occasionally  Extracurricular Participation_Not at all  \
# 40                             0.0                                       0.0
# 45                             0.0                                       0.0
# 72                             0.0                                       0.0
#
#     Extracurricular Participation_Occasionally  \
# 40                                         1.0
# 45                                         0.0
# 72                                         0.0
#
#     Extracurricular Participation_Regularly  Considered Dropping Out_Never  \
# 40                                      0.0                            1.0
# 45                                      1.0                            1.0
# 72                                      1.0                            1.0
#
#     Considered Dropping Out_Often  Considered Dropping Out_Sometimes  \
# 40                            0.0                                0.0
# 45                            0.0                                0.0
# 72                            0.0                                0.0
#
#     Experienced Bullying_Frequently  Experienced Bullying_Never  \
# 40                              0.0                         0.0
# 45                              1.0                         0.0
# 72                              0.0                         1.0
#
#     Experienced Bullying_Occasionally  \
# 40                                1.0
# 45                                0.0
# 72                                0.0
#
#     Comfort in School Environment_Comfortable  \
# 40                                        1.0
# 45                                        1.0
# 72                                        1.0
#
#     Comfort in School Environment_Somewhat Comfortable  \
# 40                                                0.0
# 45                                                0.0
# 72                                                0.0
#
#     Comfort in School Environment_Uncomfortable  \
# 40                                          0.0
# 45                                          0.0
# 72                                          0.0
#
#     Stress About Schoolwork_Always  Stress About Schoolwork_Never  \
# 40                             0.0                            0.0
# 45                             1.0                            0.0
# 72                             0.0                            0.0
#
#     Stress About Schoolwork_Rarely  Stress About Schoolwork_Sometimes  \
# 40                             0.0                                1.0
# 45                             0.0                                0.0
# 72                             0.0                                1.0
#
#     Confidence in Academic Ability_Not confident  \
# 40                                           0.0
# 45                                           0.0
# 72                                           1.0
#
#     Confidence in Academic Ability_Somewhat confident  \
# 40                                                0.0
# 45                                                0.0
# 72                                                0.0
#
#     Confidence in Academic Ability_Very confident  \
# 40                                            1.0
# 45                                            1.0
# 72                                            0.0
#
#     Access to Counseling_I'm not sure  Access to Counseling_No  \
# 40                                0.0                      0.0
# 45                                0.0                      0.0
# 72                                1.0                      0.0
#
#     Access to Counseling_Yes  Motivation for Attending School_Others  \
# 40                       1.0                                     0.0
# 45                       1.0                                     0.0
# 72                       0.0                                     0.0
#
#     Motivation for Attending School_To avoid being bored at home  \
# 40                                                0.0
# 45                                                0.0
# 72                                                0.0
#
#     Motivation for Attending School_To learn and gain knowledge  \
# 40                                                0.0
# 45                                                1.0
# 72                                                1.0
#
#     Motivation for Attending School_To meet family expectations  \
# 40                                                0.0
# 45                                                0.0
# 72                                                0.0
#
#     Motivation for Attending School_To prepare for a good career  \
# 40                                                1.0
# 45                                                0.0
# 72                                                0.0
#
#     Plan to Attend University_No  Plan to Attend University_Not Sure  \
# 40                           0.0                                 0.0
# 45                           0.0                                 0.0
# 72                           0.0                                 0.0
#
#     Plan to Attend University_Yes  JAMB Goal Score_200 To 250  \
# 40                            1.0                         0.0
# 45                            1.0                         0.0
# 72                            1.0                         0.0
#
#     JAMB Goal Score_250 To 300  JAMB Goal Score_300 And Above  \
# 40                         0.0                            1.0
# 45                         1.0                            0.0
# 72                         1.0                            0.0
#
#     JAMB Goal Score_Below 200  Foundational Knowledge_Average  \
# 40                        0.0                             0.0
# 45                        0.0                             0.0
# 72                        0.0                             0.0
#
#     Foundational Knowledge_Strong  Foundational Knowledge_Weak  \
# 40                            1.0                          0.0
# 45                            1.0                          0.0
# 72                            1.0                          0.0
#
#     Last Exam Performance_40% - 59%  Last Exam Performance_60% - 69%  \
# 40                              0.0                              0.0
# 45                              0.0                              0.0
# 72                              0.0                              0.0
#
#     Last Exam Performance_70% - 100%  Last Exam Performance_Below 40%
# 40                               1.0                              0.0
# 45                               1.0                              0.0
# 72                               1.0                              0.0

# %%
val_targets
# Out:
# 26    Likely To Succeed
# 53    Likely to Succeed
# 70       Likely To Fail
# 15    Likely to Succeed
# 45    Likely to Succeed
# 88    Likely to Succeed
# 40    Likely to Succeed
# 12    Likely To Succeed
# 72    Likely to Succeed
# 55    Likely to Succeed
# 80    Likely to Succeed
# 18    Likely to Succeed
# 90                 None
# 31    Likely to Succeed
# 22    Likely To Succeed
# Name: Next Exam Prediction, dtype: object

# %% [markdown]
# ## Training a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear')

# %%
model = LogisticRegression(solver='liblinear')

# %%
print(numeric_cols + encoded_cols)
# Out:
# ['Age Group_12 - 14', 'Age Group_15 - 16', 'Age Group_17 - 18', 'Living Situation_Both parents', 'Living Situation_Guardian', 'Living Situation_Single parent', 'Parent Education Level_Higher Education', 'Parent Education Level_No formal education', 'Parent Education Level_Post-graduate education', 'Parent Education Level_Primary school', 'Parent Education Level_Secondary school', 'Family Financial Status_We are financially comfortable', 'Family Financial Status_We can afford some luxuries', "Family Financial Status_We meet our needs but can't afford luxuries", 'Family Financial Status_We struggle to meet basic needs', 'Class_SS1', 'Class_SS2', 'Class_SS3', 'Department_Commercial', 'Department_Humanities', 'Department_Science', 'Performance in English_Excellent', 'Performance in English_Fair', 'Performance in English_Good', 'Performance in Maths_Excellent', 'Performance in Maths_Fair', 'Performance in Maths_Good', 'Performance in Maths_Poor', 'Study Hours per Week_5 - 10 hours', 'Study Hours per Week_Less than 5 hours', 'Study Hours per Week_More than 10 hours', 'Study Hours per Week_More than 15 hours', 'Extra Tutoring_No', 'Extra Tutoring_Occasionally', 'Extra Tutoring_Regularly', 'School Attendance_Every day', 'School Attendance_Most days', 'School Attendance_Occasionally', 'Extracurricular Participation_Not at all', 'Extracurricular Participation_Occasionally', 'Extracurricular Participation_Regularly', 'Considered Dropping Out_Never', 'Considered Dropping Out_Often', 'Considered Dropping Out_Sometimes', 'Experienced Bullying_Frequently', 'Experienced Bullying_Never', 'Experienced Bullying_Occasionally', 'Comfort in School Environment_Comfortable', 'Comfort in School Environment_Somewhat Comfortable', 'Comfort in School Environment_Uncomfortable', 'Stress About Schoolwork_Always', 'Stress About Schoolwork_Never', 'Stress About Schoolwork_Rarely', 'Stress About Schoolwork_Sometimes', 'Confidence in Academic Ability_Not confident', 'Confidence in Academic Ability_Somewhat confident', 'Confidence in Academic Ability_Very confident', "Access to Counseling_I'm not sure", 'Access to Counseling_No', 'Access to Counseling_Yes', 'Motivation for Attending School_Others', 'Motivation for Attending School_To avoid being bored at home', 'Motivation for Attending School_To learn and gain knowledge', 'Motivation for Attending School_To meet family expectations', 'Motivation for Attending School_To prepare for a good career', 'Plan to Attend University_No', 'Plan to Attend University_Not Sure', 'Plan to Attend University_Yes', 'JAMB Goal Score_200 To 250', 'JAMB Goal Score_250 To 300', 'JAMB Goal Score_300 And Above', 'JAMB Goal Score_Below 200', 'Foundational Knowledge_Average', 'Foundational Knowledge_Strong', 'Foundational Knowledge_Weak', 'Last Exam Performance_40% - 59%', 'Last Exam Performance_60% - 69%', 'Last Exam Performance_70% - 100%', 'Last Exam Performance_Below 40%']

# %% [markdown]
# ## Making Predictions and Evaluating the Model

# %%
# We can now use the trained model to make predictions on the training, test

X_train = train_inputs[numeric_cols + encoded_cols]
X_val = val_inputs[numeric_cols + encoded_cols]
X_test = test_inputs[numeric_cols + encoded_cols]

# %%
train_preds = model.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 train_preds = model.predict(X_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:329, in LinearClassifierMixin.decision_function(self, X)
#     310 def decision_function(self, X):
#     311     """
#     312     Predict confidence scores for samples.
#     313
#    (...)
#     327         this class would be predicted.
#     328     """
# --> 329     check_is_fitted(self)
#     330     xp, _ = get_namespace(X)
#     332     X = self._validate_data(X, accept_sparse="csr", reset=False)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1622, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1619     raise TypeError("%s is not an estimator instance." % (estimator))
#    1621 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1622     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
